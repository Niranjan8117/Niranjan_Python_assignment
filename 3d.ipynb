# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Define cycles and resistance values
cycles = np.array([0, 50, 100, 150])  
R_Z = np.linspace(20, 140, 10)  

# Create a 2D meshgrid
X, Y = np.meshgrid(R_Z, cycles)

# Initialize Z with the correct shape
Z = np.zeros_like(X, dtype=float)

# Compute Z values element-wise
Z = 30 - (X - 80) ** 2 / (40 + Y / 10) + Y * 0.1  

# Create 3D figure
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot surface
surface = ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='k', alpha=0.8)

# Labels and title
ax.set_xlabel('Re(Z) (kΩ)', fontsize=12)
ax.set_ylabel('Cycle Count', fontsize=12)
ax.set_zlabel('-Im(Z) (kΩ)', fontsize=12)
ax.set_title('EIS Measurements vs. Aging', fontsize=14)

# Add colorbar
fig.colorbar(surface, shrink=0.75, pad=0.1)

# Adjust view angle
ax.view_init(elev=20, azim=30)

plt.tight_layout()
plt.show()

# %%
pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\Admin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/104.0 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/104.0 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/104.0 kB ? eta -:--:--
#      -------------- ---------------------- 41.0/104.0 kB 393.8 kB/s eta 0:00:01
#      -----------------------------------  102.4/104.0 kB 653.6 kB/s eta 0:00:01
#      ------------------------------------ 104.0/104.0 kB 501.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#     --------------------------------------- 0.2/8.0 MB 5.0 MB/s eta 0:00:02
#    -- ------------------------------------- 0.4/8.0 MB 5.1 MB/s eta 0:00:02
# ...
